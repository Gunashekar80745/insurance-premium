# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Modify the settings for the style and size of charts
sns.set_style('darkgrid')
matplotlib.rcParams['font.size'] = 14
matplotlib.rcParams['figure.facecolor'] = '#00000000'

# %%
# Download the dataset
medical_df = pd.read_csv("../input/insurance-premium-prediction/insurance.csv")

# %%
# Take a look at the dataframe
medical_df
# Out:
#       age     sex   bmi  children smoker     region  expenses
# 0      19  female  27.9         0    yes  southwest  16884.92
# 1      18    male  33.8         1     no  southeast   1725.55
# 2      28    male  33.0         3     no  southeast   4449.46
# 3      33    male  22.7         0     no  northwest  21984.47
# 4      32    male  28.9         0     no  northwest   3866.86
# ...   ...     ...   ...       ...    ...        ...       ...
# 1333   50    male  31.0         3     no  northwest  10600.55
# 1334   18  female  31.9         0     no  northeast   2205.98
# 1335   18  female  36.9         0     no  southeast   1629.83
# 1336   21  female  25.8         0     no  southwest   2007.95
# 1337   61  female  29.1         0    yes  northwest  29141.36
#
# [1338 rows x 7 columns]

# %%
# Check the data types for each column
medical_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   expenses  1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
# We found no null values.

# %%
# Explore numerical columns stats
medical_df.describe()
# Out:
#                age          bmi     children      expenses
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.665471     1.094918  13270.422414
# std      14.049960     6.098382     1.205493  12110.011240
# min      18.000000    16.000000     0.000000   1121.870000
# 25%      27.000000    26.300000     0.000000   4740.287500
# 50%      39.000000    30.400000     1.000000   9382.030000
# 75%      51.000000    34.700000     2.000000  16639.915000
# max      64.000000    53.100000     5.000000  63770.430000

# %%
# Expenses - Mean > Median implies the data is right skewed
# Dataset looks like it has been cleaned before.

# %%
# Explore our data

# %%
# Explore our age variable.
medical_df.age.describe()
# Out:
# count    1338.000000
# mean       39.207025
# std        14.049960
# min        18.000000
# 25%        27.000000
# 50%        39.000000
# 75%        51.000000
# max        64.000000
# Name: age, dtype: float64

# %%
# Visualize age column
plt.figure(figsize=(15,7))
sns.histplot(data=medical_df, x='age', bins=47)
# Out:
# <AxesSubplot:xlabel='age', ylabel='Count'>

# %%
# Visualize age witha boxplot.
plt.figure(figsize=(13,5))
sns.boxplot(x=medical_df.age)
# Out:
# <AxesSubplot:xlabel='age'>

# %%
# Distribution for age looks almost uniform, exept for ages 18 and 19.
# Most age groups have ~25 entries.
# Why the large number of 18 and 19 year olds?

# %%
# Explore our bmi column
medical_df.bmi.describe()
# Out:
# count    1338.000000
# mean       30.665471
# std         6.098382
# min        16.000000
# 25%        26.300000
# 50%        30.400000
# 75%        34.700000
# max        53.100000
# Name: bmi, dtype: float64

# %%
# Visualize our BMI column.
plt.figure(figsize=(15,7))
sns.histplot(data=medical_df, x='bmi')
# Out:
# <AxesSubplot:xlabel='bmi', ylabel='Count'>

# %%
# Visualize age witha boxplot.
plt.figure(figsize=(13,5))
sns.boxplot(x=medical_df.bmi)
# Out:
# <AxesSubplot:xlabel='bmi'>

# %%
# Histogram shows a Gaussian Distribution
# Boxplot does show we have some outliers.

# %%
# Explore our charges column
medical_df.expenses.describe()
# Out:
# count     1338.000000
# mean     13270.422414
# std      12110.011240
# min       1121.870000
# 25%       4740.287500
# 50%       9382.030000
# 75%      16639.915000
# max      63770.430000
# Name: expenses, dtype: float64

# %%
# Visualize our expenses column.
plt.figure(figsize=(15,7))
sns.histplot(data=medical_df, x='expenses')
# Out:
# <AxesSubplot:xlabel='expenses', ylabel='Count'>

# %%
# Visualize expenses witha boxplot.
plt.figure(figsize=(13,5))
sns.boxplot(x=medical_df.expenses)
# Out:
# <AxesSubplot:xlabel='expenses'>

# %%
# Visualize by adding the smoker variable in.
# Visualize our expenses column.
plt.figure(figsize=(15,7))
sns.histplot(data=medical_df, x='expenses', hue='smoker')
# Out:
# <AxesSubplot:xlabel='expenses', ylabel='Count'>

# %%
# Expenses column seems to have a positive skew.
# Most people have expenses under 17k
# Smokers seem to have higher charges.

# %%
# Explore our smokers column
medical_df.smoker.value_counts()
# Out:
# no     1064
# yes     274
# Name: smoker, dtype: int64

# %%
# Visualize smoker column
plt.figure(figsize=(12,7))
sns.countplot(x=medical_df.smoker)
# Out:
# <AxesSubplot:xlabel='smoker', ylabel='count'>

# %%
# Visualize by smoker by sex
plt.figure(figsize=(12,7))
sns.countplot(x=medical_df.smoker, hue=medical_df.sex)
# Out:
# <AxesSubplot:xlabel='smoker', ylabel='count'>

# %%
# Most people do not smoke or report that they do not smoke.
# Men seem most likely to report that they smoke.

# %%
# Now we take a look at the relationship between variables.

# %%
# Explore relationship between AGE and CHARGES
plt.figure(figsize=(15,7))
sns.regplot(x=medical_df.age, y=medical_df.expenses)
# Out:
# <AxesSubplot:xlabel='age', ylabel='expenses'>

# %%
# Explore relationship between BMI and CHARGES
plt.figure(figsize=(15,7))
sns.regplot(x=medical_df.bmi, y=medical_df.expenses)
# Out:
# <AxesSubplot:xlabel='bmi', ylabel='expenses'>

# %%
plt.figure(figsize=(15,7))
sns.scatterplot(x=medical_df.bmi, y=medical_df.expenses,hue=medical_df.smoker )
# Out:
# <AxesSubplot:xlabel='bmi', ylabel='expenses'>

# %%
# Smokers BMI vs Expenses
plt.figure(figsize=(15,7))
smoker_df = medical_df[medical_df['smoker'] == 'yes']
sns.regplot(x=smoker_df.bmi, y=smoker_df.expenses)
# Out:
# <AxesSubplot:xlabel='bmi', ylabel='expenses'>

# %%
# Non-Smokers BMI vs Expenses
plt.figure(figsize=(15,7))
smoker_df = medical_df[medical_df['smoker'] == 'no']
sns.regplot(x=smoker_df.bmi, y=smoker_df.expenses)
# Out:
# <AxesSubplot:xlabel='bmi', ylabel='expenses'>

# %%
# Expenses do not seem to increase with bmi of non smokers.
# Smokers expenses increase with bmi.

# %%
# Explore other expenses relationships.
plt.figure(figsize=(15,7))
sns.barplot(x=medical_df.children, y=medical_df.expenses)
# Out:
# <AxesSubplot:xlabel='children', ylabel='expenses'>

# %%
plt.figure(figsize=(15,7))
sns.barplot(x=medical_df.region, y=medical_df.expenses)
# Out:
# <AxesSubplot:xlabel='region', ylabel='expenses'>

# %%
# People with 5 children have the lowest expenses.
# People in the southeast region have highest expenses, and people in northwest have lowest.

# %%
# Find the correlation coefficient of our columns.

# %%
medical_df.expenses.corr(medical_df.age)
# Out:
# 0.2990081922850828

# %%
medical_df.expenses.corr(medical_df.bmi)
# Out:
# 0.19857625501893206

# %%
medical_df.expenses.corr(medical_df.children)
# Out:
# 0.06799823000532808

# %%
# visualize correlation using a heatmap
plt.figure(figsize=(14,8))
cor = medical_df.corr()
sns.heatmap(cor, annot=True, fmt='.1g', cmap='Blues')
# Out:
# <AxesSubplot:>

# %%
# We do not seem to have strong correlation between variables.

# %%
# See relationship between expenses and smokers
# First convert datatype to numerical
smoker_values = {'no': 0, 'yes': 1}
smoker_numeric = medical_df.smoker.map(smoker_values)
smoker_numeric
# Out:
# 0       1
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 1333    0
# 1334    0
# 1335    0
# 1336    0
# 1337    1
# Name: smoker, Length: 1338, dtype: int64

# %%
medical_df.expenses.corr(smoker_numeric)
# Out:
# 0.7872514298985541

# %%
# create a df with smoker value as numeric
smoker_num_df = medical_df.replace(['yes', 'no'], [1, 0])

# %%
smoker_num_df.expenses.corr(smoker_num_df.smoker)
# Out:
# 0.7872514298985541

# %%
plt.figure(figsize=(14,8))
cor = smoker_num_df.corr()
sns.heatmap(cor, annot=True, fmt='.1g', cmap='Blues')
# Out:
# <AxesSubplot:>

# %%
# Lets build a linear regression model for non smokers.

# %%
X = medical_df.iloc[: , :-1]
Y = medical_df.iloc[: , 6]

# %%
X
# Out:
#       age     sex   bmi  children smoker     region
# 0      19  female  27.9         0    yes  southwest
# 1      18    male  33.8         1     no  southeast
# 2      28    male  33.0         3     no  southeast
# 3      33    male  22.7         0     no  northwest
# 4      32    male  28.9         0     no  northwest
# ...   ...     ...   ...       ...    ...        ...
# 1333   50    male  31.0         3     no  northwest
# 1334   18  female  31.9         0     no  northeast
# 1335   18  female  36.9         0     no  southeast
# 1336   21  female  25.8         0     no  southwest
# 1337   61  female  29.1         0    yes  northwest
#
# [1338 rows x 6 columns]

# %%
Y
# Out:
# 0       16884.92
# 1        1725.55
# 2        4449.46
# 3       21984.47
# 4        3866.86
#           ...
# 1333    10600.55
# 1334     2205.98
# 1335     1629.83
# 1336     2007.95
# 1337    29141.36
# Name: expenses, Length: 1338, dtype: float64

# %%
# Create dummy variables for categorical features.
smoker = pd.get_dummies(X['smoker'], drop_first=True)
region = pd.get_dummies(X['region'], drop_first=True)
sex = pd.get_dummies(X['sex'], drop_first=True )

# %%
X = X.drop(columns=['sex'])
X = pd.concat([X, sex], axis=1)

# %%
#Drop old column and concat new dummy columns.
X = X.drop(columns=['region'])

# %%
X = pd.concat([X, region], axis=1)

# %%
X = X.drop(columns=['smoker'])
X = pd.concat([X, smoker], axis=1)

# %%
X.rename(columns={'yes': 'smoker'}, inplace=True)

# %%
X = X.astype({'male': 'int64', 'northwest': 'int64', 'southeast': 'int64', 'southwest': 'int64' , 'smoker': 'int64'})

# %%
X.dtypes
# Out:
# age            int64
# bmi          float64
# children       int64
# male           int64
# northwest      int64
# southeast      int64
# southwest      int64
# smoker         int64
# dtype: object

# %%
# Split data into Training and Test sets.
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=0)

# %%
# Fit Model to the training set
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# Predict the test set result
y_pred = regressor.predict(X_test)

# %%
#
from sklearn.metrics import r2_score
score = r2_score(y_test, y_pred)

# %%
score
# Out:
# 0.8000184017333828

# %%
# We have a R^2 score of 0.8 which tells us that our model is accurate.
